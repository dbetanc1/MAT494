# %% [markdown]
# <a href="https://colab.research.google.com/github/dbetanc1/MAT494/blob/main/HW_3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 3
# Calculus and Optimization

# %% [markdown]
# # 3.2 Continunity and Differentiation
#
# 3.2.1 Limits and Continuity
#
# Limits are essential to calculus and mathematical analysis, and are used to
# define continuity, derivatives, and integrals.
# ![image.png](data:image/png;base64,...)
#
# The open r-ball around x ∈ R^d is the set of points within Euclidean distance r of x, that is,
# ![image.png](data:image/png;base64,...)
# Continuous function is a function that does not have any abrupt changes
# in value, known as discontinuities. The definition of continuity of a function
# can be visualized in Figure 3.3. Note that we explicitly exclude a itself from
# having to satisfy the condition | f (x)− L| <ε. In particular, we may have
# f (a)̸=L. We also do not restrict a to be in D.
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3.2.2 Derivatives

# %% [markdown]
# 3.2.2.1 Single-Variable Case
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
